# %% [markdown]
# # Data Project Pitch

# %% [markdown]
# ### Σύνοψη

# %% [markdown]
# Στις χώρες της Μέσης Ανατολής επικρατούν καθεστώτα αντιδημοκρατικά, καθώς επίσης οι εντάσεις και οι εμπόλεμες συρράξεις είναι συχνό -ακόμα και δεδομένο- φαινόμενο. Σε τέτοιες περιπτώσεις ενώ η δημοσιογραφία είναι πιο σημαντική από ποτέ, τελικά πλήττεται και φιμώνεται με πολλούς δημοσιογράφους είτε να φυλακίζονται, είτε να χάνουν τη ζωή τους, είτε να παραμένουν αγνοούμενοι. Θα επιχειρήσουμε να εξετάσουμε τις πιθανές διαφοροποιήσεις με βάση το φύλο, το αν υποστηρίζονται από κάποιο μέσο ή όχι και τη χώρα που δραστηριοποιούνται κατά τη διάρκεια του 2022.

# %% [markdown]
# ### Έμπνευση

# %% [markdown]
# - https://cpj.org/2023/11/journalist-casualties-in-the-israel-gaza-conflict/
# - https://rsf.org/en/seven-journalists-killed-line-duty-gaza-and-lebanon-past-seven-days-bloody-week-journalism-middle

# %%
from IPython.display import Image
Image(filename="clustered column chart.png")

# %%
from IPython.display import Image
Image(filename="chart.png")

# %% [markdown]
# ### Περαιτέρω πληροφορίες για το θέμα σας

# %% [markdown]
# ΤΙΤΛΟΙ:
# - Τί εστί να είσαι δημοσιογράφος στη Μέση Ανατολή;
#
# ΔΕΔΟΜΕΝΑ:
# - https://cpj.org/data/killed/?status=Killed&motiveConfirmed%5B%5D=Confirmed&motiveUnconfirmed%5B%5D=Unconfirmed&type%5B%5D=Journalist&type%5B%5D=Media%20Worker&start_year=1992&end_year=2023&group_by=year
# - https://cpj.org/data/imprisoned/2022/?status=Imprisoned&start_year=2022&end_year=2022&group_by=location
# - https://cpj.org/data/missing/?status=Missing&start_year=2023&end_year=2023&group_by=location
#
# ΠΙΘΑΝΑ ΠΡΟΒΛΗΜΑΤΑ:
# - Scrapping
# - Έκταση κειμένου

# %% [markdown]
# ### Ερευνητικά ερωτήματα

# %% [markdown]
# - Πόσο επικίνδυνο είναι να εργάζεσαι ως δημοσιογράφος στη Μέση Ανατολή;
# - Ποιες διαφορές υπάρχουν με βάση το φύλο;
# - Ποιες διαφορές υπάρχουν με βάση το αν υποστηρίζεται ο δημοσιογράφος από μέσο (ή οργανισμό) ή όχι;
# - Ποιες διαφορές υπάρχουν με βάση τη χώρα δραστηριοποίησης του δημοσιογράφου;

# %% [markdown]
# ### Προέρευνα/δουλειά που έχετε ήδη κάνει στο πλαίσιο του σχεδιασμού του πρότζεκτ

# %% [markdown]
# - Έχουμε βρει δεδομένα, τα έχουμε κοιτάξει online, όμως δεν τα έχουμε καθαρίσει.

# %%
from IPython.display import Image
Image(filename="chart.png")

# %% [markdown]
# ## Απαντήστε "YES" ή "NO" στα παρακάτω ερωτήματα
# <i>(Στο στάδιο της πρότασης θέματος που βρίσκεστε, το αναμενόμενο είναι YES. Όσα περισσότερα NO, τόσο λιγότερο έχετε προετοιμαστεί και, άρα, χρειάζεται να σχεδιάσετε καλύτερα το πρότζεκτ σας.)</i>

# %%
input("Έχετε ψάξει για πηγές δεδομένων για το θέμα που θέλετε να κάνετε;")
# Out:
# Έχετε ψάξει για πηγές δεδομένων για το θέμα που θέλετε να κάνετε; YES
# 'YES'

# %%
input("Έχετε βρει δεδομένα/πηγές δεδομένων για το θέμα που θέλετε να κάνετε;")
# Out:
# Έχετε βρει δεδομένα/πηγές δεδομένων για το θέμα που θέλετε να κάνετε; YES
# 'YES'

# %%
input("Έχετε περάσει χρόνο εξερευνώντας τα δεδομένα σας; Έχετε καταλάβει τι έχετε, σε ποια μορφή είναι και ενδεχομένως τι σας λείπει;")
# Out:
# Έχετε περάσει χρόνο εξερευνώντας τα δεδομένα σας; Έχετε καταλάβει τι έχετε, σε ποια μορφή είναι και ενδεχομένως τι σας λείπει; YES
# 'YES'

# %%
input("Έχετε διατυπώσει τα ερευνητικά ερωτήματά σας;")
# Out:
# Έχετε διατυπώσει τα ερευνητικά ερωτήματά σας; YES
# 'YES'

# %%
input("Έχετε σκεφτεί πώς θα αναλύσετε τα δεδομένα σας, για να απαντήσετε τα ερευνητικά ερωτήματά σας;")
# Out:
# Έχετε σκεφτεί πώς θα αναλύσετε τα δεδομένα σας, για να απαντήσετε τα ερευνητικά ερωτήματά σας; YES
# 'YES'

# %%
input("Έχετε αρχίσει να σκέφτεστε πώς θα μπορούσατε να οπτικοποιήσετε τις αναλύσεις σας για το τελικό σας story;")
# Out:
# Έχετε αρχίσει να σκέφτεστε πώς θα μπορούσατε να οπτικοποιήσετε τις αναλύσεις σας για το τελικό σας story; YES
# 'YES'

# %%
input("Έχετε καταθέσει το pitch σας (το προτεινόμενο θέμα σας) σε ένα notebook με filename PITCH_ΟΝΟΜΑΤΕΠΩΝΥΜΟ1_ΟΝΟΜΑΤΕΠΩΝΥΜΟ2;")
# Out:
# Έχετε καταθέσει το pitch σας (το προτεινόμενο θέμα σας) σε ένα notebook με filename PITCH_ΟΝΟΜΑΤΕΠΩΝΥΜΟ1_ΟΝΟΜΑΤΕΠΩΝΥΜΟ2; YES
# 'YES'
